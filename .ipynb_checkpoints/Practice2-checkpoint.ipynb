# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
linear_data=np.arange(1,8)
quadratic_data=linear_data**2

# %%
x=np.arange(1,8)

# %%
# %matplotlib notebook

# %%
plt.figure()
s1=plt.subplot(1,2,1)

s1.plot(x,linear_data,'-r',label='linear data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s2=plt.subplot(1,2,2)
s2.plot(x,quadratic_data,'-b',label='quadratic data')
plt.show()

# %%
s1.set_xlabel('X')
s1.set_ylabel('Linear Data')
s1.set_title('Linear Data')
s1.legend()

s2.set_xlabel('X')
s2.set_ylabel('quadratic Data')
s2.set_title('Quadratic Data')
s2.legend()

# %%
plt.suptitle('Aamchi shakha kuthe hi nahi')
# Out:
# Text(0.5, 0.98, 'Aamchi shakha kuthe hi nahi')

# %%
plt.savefig('common_labels.png', dpi=600)

# %%
plt.sca(s1)

# %%
s1.set_xticks(x)
s1.set_xticklabels(['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
# Out:
# [Text(0.0, 0, 'Mon'),
#  Text(2.0, 0, 'Tue'),
#  Text(4.0, 0, 'Wed'),
#  Text(6.0, 0, 'Thu'),
#  Text(8.0, 0, 'Fri'),
#  Text(0, 0, 'Sat'),
#  Text(0, 0, 'Sun')]

# %%
plt.show()

# %%
plt.draw()

# %%
for ax in plt.gcf().get_axes():
    for spine in ax.spines.values():
        spine.set_visible(False)

# %%
for ax in plt.gcf().get_axes():
    ax.tick_params(top=False,bottom=False,left=False,right=False,labelleft=False,labelright=False,labeltop=False,labelbottom=False)

# %%
plt.show()

# %%
labels=s1.get_xticklabels()

# %%
# Out:
# <a list of 0 Text xticklabel objects>
